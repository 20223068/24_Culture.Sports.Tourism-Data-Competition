# %%
import pandas as pd

# %%
data = pd.read_csv('공연예술조사_공연시설_2023(2022기준)_데이터.csv', encoding='utf-8')
print(data.head())
# Out:
#    NID  FAC1  FAC2  LOC1  LOC2  LOC3  LOC4  ETYPE1  ETYPE2  OTYPE1  ...  \
# 0    2     5     2     9     2     2     1       9       2       9  ...
# 1    9     4     2     1     1     1     1       7       2       9  ...
# 2   11     4     2     1     1     1     1       7       2       7  ...
# 3   18     5     2     5     5     1     2       9       2       9  ...
# 4   19     5     2     7     6     1     2       7       2       7  ...
#
#    QQ2_1_2A  QQ2_1_3A  QQ2_1_4A QQ2_1_2B QQ2_1_3B QQ2_1_4B  QQ2_2_1A  \
# 0       NaN       NaN       NaN      NaN      NaN      NaN       NaN
# 1       NaN       NaN       NaN      NaN      NaN      NaN       NaN
# 2       NaN       NaN       NaN      NaN      NaN      NaN       NaN
# 3       NaN       NaN       NaN      NaN      NaN      NaN       NaN
# 4       NaN       NaN       NaN      NaN      NaN      NaN       NaN
#
#    QQ2_2_2A  QQ2_2_3A  WT
# 0       NaN       NaN NaN
# 1       NaN       NaN NaN
# 2       NaN       NaN NaN
# ...
